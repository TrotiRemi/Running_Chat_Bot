# %% [markdown]
# # Chapter 6 - Exercises
#
# > Author : Badr TAJINI - Large Language model (LLMs) - ESIEE 2024-2025
#
# ---

# %% [markdown]
# ## Exercise 6.1: Increasing the context length

# %% [markdown]
# **Padding Input Sequences in Neural Language Models**
#
# **Key Research Question: How does padding inputs to the maximum `token` length affect model predictive performance?**
#
# *Methodological Approach:*
# - Implement systematic `token` padding
# - Analyze padding's impact on model performance
# - Explore input representation interactions
#
# *Critical Parameters:*
# - Input `padding` strategy
# - Maximum `token` length
# - Predictive performance metrics
#
# *Recommended Investigation:*
# 1. Implement maximum-length input `padding`
# 2. Measure performance variations
# 3. Compare padded versus non-padded inputs
# 4. Assess computational implications

# %% [markdown]
# ### Résultats - Exercise 6.1

# %% [markdown]
# J'ai tout simplement sur Collab repris le lab6 et dans la partie 6.3 j'ai rajouter un max_length = 1024 et ensuite j'ai modifier pour les trois dataset le max_length par celui-ci.

# %% [markdown]
# #### Performance token length = 1024

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Interprétation**
# On remarque que cela donne de moins bon résultats que la config de base (CF les performance de base qui sont tout en bas de ipynb))

# %% [markdown]
# ## Exercise 6.2: Finetuning the whole model

# %% [markdown]
# **Model-Wide Fine-Tuning Performance Assessment**
#
# **Key Research Question: What is the impact of `fine-tuning` the entire transformer model versus a single final block on predictive performance?**
#
#
# *Methodological Approach:*
# - Implement comprehensive model `fine-tuning`
# - Compare performance against single block tuning
# - Assess computational and representational changes
#
# *Critical Parameters:*
# - Full model `fine-tuning` strategy
# - Performance evaluation metrics
# - Comparative analysis methodology
#
# *Recommended Investigation:*
# 1. `Fine-tune` entire transformer model
# 2. Measure predictive performance metrics
# 3. Compare with previous single-block tuning results
# 4. Analyze performance variation mechanisms

# %% [markdown]
# ### Résultats - Exercise 6.2

# %% [markdown]
# J'ai tout simplement sur Collab repris le lab6 et dans la partie 6.5 j'ai supprimer
#
# for param in model.parameters():
#     param.requires_grad = False
#
# pour tout simplement fine tunner tout le modèle car cela ne freeze aucun layer et rend le tout trainable donc fine tunable.

# %% [markdown]
# #### Performance Fine Tunning the whole Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Interprétation**
# On remarque qu'il y a une toute petite améliorations de environ 1% si on fine tune tout le modèle (CF les performance de base qui sont tout en bas de ipynb)

# %% [markdown]
# ## Exercise 6.3: Finetuning the first versus last token

# %% [markdown]
# **First Token Fine-Tuning: Predictive Performance Analysis**
#
# **Key Research Question: How do predictive performance characteristics change when fine-tuning the first output `token` compared to the last output `token`?**
#
# *Methodological Approach:*
# - Fine-tune first output `token`
# - Compare performance against last `token` fine-tuning
# - Assess representational learning variations
#
# *Critical Parameters:*
# - Initial `token` fine-tuning strategy
# - Performance evaluation metrics
# - Comparative analysis methodology
#
# *Recommended Investigation:*
# 1. Implement first `token` fine-tuning
# 2. Measure predictive performance
# 3. Compare with last `token` fine-tuning results
# 4. Analyze performance variation mechanisms

# %% [markdown]
# ### Résultats - Exercise 6.3

# %% [markdown]
# J'ai tout simplement sur Collab repris le lab6 et dans la partie 6.6 j'ai modifier les lignes model(input_batch)[:, -1, :] par model(input_batch)[:, -1, :] dans les méthodes calc_accuracy_loader() et calc_loss_batch() pour tout simplement fine tunner le first output token au lieu du last.

# %% [markdown]
# #### Performance first output token

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Interprétation**
# On a donc des résultats bien moins interrésants si l'on fine tune le first output token (CF les performance de base qui sont tout en bas de ipynb)

# %% [markdown]
# #### Performance de base

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
